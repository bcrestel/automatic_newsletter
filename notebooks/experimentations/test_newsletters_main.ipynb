# %%
from src.newsletters.main import runner as runner_newsletters
from src.scoring.main import runner as runner_scoring

# %%
news_stories = runner_newsletters(after='2024-12-01', before='2024-12-08')
len(news_stories)
# Out:
# 2024-12-15 04:57:07,388 - googleapiclient.discovery_cache - INFO -- l.49: file_cache is only supported with oauth2client<4.0.0
# 2024-12-15 04:57:07,393 - src.newsletters.main - INFO -- l.31: Query emails
# 2024-12-15 04:57:09,102 - src.newsletters.main - INFO -- l.37: Using 1 sender(s): dict_keys(['TLDR AI <dan@tldrnewsletter.com>']).
# 2024-12-15 04:57:09,103 - src.newsletters.main - INFO -- l.42: Parsing emails to extract news stories
# 2024-12-15 04:57:09,105 - src.newsletters.main - INFO -- l.49: Newsletters block complete. Found 60 news stories.
# 60

# %%
news_stories
# Out:
# [{'title': 'OPENAI O1 SYSTEM CARD',
#   'url': 'https://links.tldrnewsletter.com/xS4pwo',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "This report outlines the safety work carried out prior to releasing OpenAI o1 and o1-mini, including external red teaming and frontier risk evaluations according to OpenAI's Preparedness Framework.",
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': "PERPLEXITY EXPANDING IT'S PUBLISHER'S PROGRAM",
#   'url': 'https://links.tldrnewsletter.com/UUkpwY',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Perplexity has added over a dozen international news organizations to its Publishers' Program, offering tools, revenue sharing, and support to strengthen collaboration with global media.",
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': "DEEPMIND'S GENIE 2 CAN GENERATE INTERACTIVE WORLDS THAT LOOK LIKE\r\nVIDEO GAMES",
#   'url': 'https://techcrunch.com/2024/12/04/deepminds-genie-2-can-generate-interactive-worlds-that-look-like-video-games/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "DeepMind's Genie 2 is an advanced AI model that generates diverse, interactive 3D worlds from images and text descriptions. The model is particularly adept at simulating complex elements like physics and NPC behavior, setting it apart from similar models by maintaining scene consistency. Positioned as a research tool, Genie 2 is designed for prototyping interactive experiences and evaluating AI agents.",
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': 'PALIGEMMA 2',
#   'url': 'https://arxiv.org/abs/2412.03555?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Paligemma 2 is one of the best VLMs on the market today. It uses SigLIP and Gemma.',
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': 'LAND COVER MAPPING WITH ASANET',
#   'url': 'https://arxiv.org/abs/2412.02044v1?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'The Asymmetric Semantic Aligning Network (ASANet) improves land cover classification using both SAR and RGB images.',
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': 'FASTER MULTI-MODAL MODELS WITH TOKEN MERGING',
#   'url': 'https://arxiv.org/abs/2412.03248v1?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Researchers have developed a training-free method to make multi-modal language models (LLMs) more efficient without sacrificing much performance. Their approach reduces computational demands by up to 7 times by smartly merging and pruning visual data tokens.',
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': 'NEW FISH AUDIO MODEL',
#   'url': 'https://threadreaderapp.com/thread/1864370933496205728.html?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'The newest Fish Audio 1.5 is currently #2 on Text To Speech Leaderboards behind ElevenLabs. It supports voice cloning and is fast to run, although the output quality seems hit or miss.',
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': 'OPENAI PARTNERS WITH ANDURIL',
#   'url': 'https://www.cnbc.com/2024/12/04/openai-partners-with-defense-company-anduril.html?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'OpenAI and defense company Anduril have partnered to create a national security-based AI.',
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': "KEY LEADERS BEHIND GOOGLE'S VIRAL NOTEBOOKLM ARE LEAVING TO CREATE\r\nTHEIR OWN STARTUP",
#   'url': 'https://techcrunch.com/2024/12/04/key-leaders-behind-googles-viral-notebooklm-are-leaving-to-create-their-own-startup/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Three key Google NotebookLM members have left to start a new stealth AI venture. The startup aims to leverage the latest AI models to create consumer-facing, user-first AI products. It remains in its early stages without a clear focus or announced funding.',
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': 'GUI AGENTS',
#   'url': 'https://vyokky.github.io/LLM-Brained-GUI-Agents-Survey/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'A collection of research papers and projects on large language model-brained GUI agents.',
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': 'SAM ALTMAN SAYS ARTIFICIAL GENERAL INTELLIGENCE IS ON THE HORIZON',
#   'url': 'https://www.nytimes.com/video/business/100000009858580/sam-altman-openai-dealbook.html?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Sam Altman, CEO of OpenAI, stated at the DealBook Summit that Artificial General Intelligence might impact everyday life less significantly than expected.',
#   'date_source': 'Fri, 6 Dec 2024 14:16:24 +0000'},
#  {'title': 'OPENAI 12 DAYS OF SHIPMAS',
#   'url': 'https://threadreaderapp.com/thread/1864335461268754712.html?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'OpenAI will be having 12 live streams over the next 12 days to ship new product and model features.',
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': "META'S NUCLEAR ENERGY PLANS",
#   'url': 'https://sustainability.atmeta.com/blog/2024/12/03/accelerating-the-next-wave-of-nuclear-to-power-ai-innovation/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Meta announced plans to collaborate with nuclear energy developers through a new request for proposals. The initiative aims to add 1-4 gigawatts of nuclear capacity in the U.S. to support Meta's AI innovation and sustainability efforts.",
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'AWS REINVENT TOP ANNOUNCEMENTS',
#   'url': 'https://aws.amazon.com/blogs/aws/top-announcements-of-aws-reinvent-2024/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'AWS announced various additions and tools including bringing prompt routing and caching to its Bedrock LLM service at AWS re:Invent 2024.',
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'GENIE 2: A LARGE-SCALE FOUNDATION WORLD MODEL',
#   'url': 'https://deepmind.google/discover/blog/genie-2-a-large-scale-foundation-world-model/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Genie 2 is a large scale latent diffusion model for world generation. It works with character control as input and is also classifier free. The outputs are stunning and maintain control and consistency over time.',
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'MOTION PROMPTING',
#   'url': 'https://motion-prompting.github.io/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Motion Prompting is a method that trains a video generation model with novel input types. Instead of just text or an image, it uses text, first image frame, and a tracking field of pixels. This then allows for novel control at inference time where it can provide a new pixel field (e.g., for an object moving in a new direction) and generate a video based on that. The method is extremely compelling, but not open sourced.',
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'DYNAMIC 4-BIT QUANTIZATION',
#   'url': 'https://unsloth.ai/blog/dynamic-4bit?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'The Unsloth team aims to shrink a 20GB language model into 5GB without sacrificing accuracy. There are many algorithms that attempt this, but there are a number of challenges around outliers and compressibility. Llama is a famously hard model to quantize. The method selectively avoids quantizing certain parameters, which greatly improves overall accuracy.',
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'OPTIMIZING AI INFERENCE AT CHARACTER AI',
#   'url': 'https://research.character.ai/optimizing-ai-inference-at-character-ai-part-deux/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Character AI has a strong inference pipeline. In this post, the team walks through their int8 quantization and flash attention 3 implementation. It's a good read for folks interested in serving large language models at scale.",
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'CERTAIN NAMES MAKE CHATGPT GRIND TO A HALT, AND WE KNOW WHY',
#   'url': 'https://arstechnica.com/information-technology/2024/12/certain-names-make-chatgpt-grind-to-a-halt-and-we-know-why/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "OpenAI's ChatGPT employs hard-coded filters to prevent the AI from generating false statements about specific individuals, leading to broken conversations when these names are mentioned. This approach stems from past incidents like defamation lawsuits against OpenAI, prompting the company to restrict outputs related to contentious names. The hard-coded filters can pose challenges as they limit ChatGPT's functionality and leave the system vulnerable to adversarial attacks.",
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'FINETUNING LLM JUDGES FOR EVALUATION',
#   'url': 'https://cameronrwolfe.substack.com/p/finetuned-judge?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Evaluating LLMs has become challenging due to their complex and open-ended outputs. Traditional evaluation relies on human judgment, which is detailed but inefficient. Thus, automatic metrics and model-based evaluations like LLM-as-a-Judge are crucial for scalable assessment. Innovations such as specialized fine tuned judges (e.g., Prometheus) and synthetic data generation are enhancing LLM evaluation's precision and adaptability across diverse tasks and domains.",
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'FLOW',
#   'url': 'https://github.com/lmnr-ai/flow?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Flow is a lightweight engine for creating flexible AI workflows using dynamic task scheduling and concurrent execution.',
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'THE GEN AI BRIDGE TO THE FUTURE',
#   'url': 'https://stratechery.com/2024/the-gen-ai-bridge-to-the-future/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Generative AI is set to revolutionize wearable technology by creating on-demand UI interfaces that adapt to user needs and context.',
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': "WORLD LABS' AI CAN GENERATE INTERACTIVE 3D SCENES FROM A SINGLE PHOTO",
#   'url': 'https://techcrunch.com/2024/12/02/world-labs-ai-can-generate-interactive-3d-scenes-from-a-single-photo/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'World Labs, founded by AI expert Fei-Fei Li, has introduced an AI system capable of generating interactive 3D scenes from a single image.',
#   'date_source': 'Thu, 5 Dec 2024 14:13:29 +0000'},
#  {'title': 'ELEVEN LABS CONVERSATIONAL AI',
#   'url': 'https://elevenlabs.io/conversational-ai?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Eleven Labs has launched a new conversational AI service that is more of an end-to-end product for building conversational agents. It uses a variety of LLMs on the backend while integrating seamlessly to a wide variety of specialized voices.',
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'CLAUDE MODELS NOW FASTER AND SMARTER ON AWS TRAINIUM2',
#   'url': 'https://www.anthropic.com/news/trainium2-and-distillation?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Claude models are being optimized for AWS' advanced Trainium2 AI chips. This will enable faster and more efficient performance. Claude 3.5 Haiku is now available on AWS Trainium2 and model distillation in Amazon Bedrock.",
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'AMAZON LAUNCHES NOVA',
#   'url': 'https://aws.amazon.com/blogs/aws/introducing-amazon-nova-frontier-intelligence-and-industry-leading-price-performance/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Amazon Nova introduces a suite of multimodal models designed for tasks like document analysis, visual understanding, and creative content generation. With a focus on customization and efficiency, Nova models cater to diverse enterprise needs while excelling in tasks that combine text, image, and video inputs.',
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'DIFFUSION MEETS FLOW MATCHING: TWO SIDES OF THE SAME COIN',
#   'url': 'https://diffusionflow.github.io/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'This post talks through some of the literature and shows that, mathematically, both flow matching and diffusion models are the same. Interestingly, flow matching still seems to scale better practically.',
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'RESTRUCTURING VECTOR QUANTIZATION WITH THE ROTATION TRICK',
#   'url': 'https://arxiv.org/abs/2410.06424?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Vector Quantization relies on gradient estimation through what's known as the Straight Through Gradient estimator. However, its direction is sometimes incorrect. This paper suggests rotation as a way to fix the gradients and improve code book utilization.",
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'LAYOUT GENERATION WITH DIFFUSION GANS',
#   'url': 'https://arxiv.org/abs/2412.00381v1?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'DogLayout is a hybrid model that combines GANs and diffusion processes to overcome challenges in layout generation.',
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'A SYSTEM OF AGENTS BRINGS SERVICE-AS-SOFTWARE TO LIFE',
#   'url': 'https://foundationcapital.com/system-of-agents/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'AI is transitioning software from a tool to autonomous agents capable of executing tasks traditionally performed by humans, with a projected $4.6 trillion market opportunity. Innovations such as LLMs and agents enable AI systems to process unstructured data, make decisions, and act autonomously across sectors like sales and healthcare. The future of AI involves Systems of Agents that collaborate and learn from each other, functioning like a highly skilled team to deliver services.',
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': "AI MUSIC IS MORE REALISTIC THAN EVER: MEET SUNO'S NEW MODEL",
#   'url': 'https://www.rollingstone.com/music/music-features/ai-music-generator-new-model-suno-1235172581/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Suno has become the fifth most-used generative AI service with its realistic AI music model V4, despite facing a copyright lawsuit. The model improves user experience by focusing on human preferences, offering enhanced sound quality and advanced composition skills. Suno aims to advance AI-human music collaboration while addressing copyright concerns with the recording industry.',
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': "BLUESKY'S OPEN API MEANS ANYONE CAN SCRAPE YOUR DATA FOR AI TRAINING",
#   'url': 'https://techcrunch.com/2024/11/27/blueskys-open-api-means-anyone-can-scrape-your-data-for-ai-training/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Bluesky isn't using user content to train AI, but third parties like Hugging Face have accessed posts for machine learning research. This highlights the public nature of user posts and the challenges in controlling third-party use. Bluesky is exploring ways for users to convey consent, but enforcement outside its platform remains a challenge.",
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'AISUITE',
#   'url': 'https://github.com/andrewyng/aisuite?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'aisuite provides a unified interface for seamless interaction with multiple LLM providers, aiding developers in testing and comparing outputs without altering code.',
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'OVER ½ OF LONG POSTS ON LINKEDIN ARE LIKELY AI-GENERATED SINCE\r\nCHATGPT LAUNCHED',
#   'url': 'https://originality.ai/blog/ai-content-published-linkedin?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Since ChatGPT's launch, LinkedIn has seen an 189% surge in AI-generated content, with over half of long-form posts now likely AI-driven.",
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'GOOGLE LAUNCHES THE LONDON AI CAMPUS',
#   'url': 'https://blog.google/around-the-globe/google-europe/united-kingdom/google-launches-ai-campus-london/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'The AI Campus is an educational pilot to support and diversify the next generation of local AI talent.',
#   'date_source': 'Wed, 4 Dec 2024 14:15:46 +0000'},
#  {'title': 'ADS MIGHT BE COMING TO CHATGPT',
#   'url': 'https://techcrunch.com/2024/12/02/ads-might-be-coming-to-chatgpt-despite-sam-altman-not-being-a-fan/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'OpenAI is considering an advertising business model to help support its costly AI tool development. Despite no current active plans for ads, the idea remains on the table as a potential revenue source. CEO Sam Altman considers ads a last resort and has expressed discomfort at the possibility of combining ads and AI.',
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': 'THE RACE IS ON TO MAKE AI AGENTS DO YOUR ONLINE SHOPPING FOR YOU',
#   'url': 'https://techcrunch.com/2024/12/02/the-race-is-on-to-make-ai-agents-do-your-online-shopping-for-you/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Tech companies are developing AI shopping agents to automate online purchases, potentially reshaping the retail industry. Perplexity's current model faces operational challenges. Companies like OpenAI, Google, and Amazon are also exploring AI purchasing capabilities. These developments aim to streamline shopping but raise questions about privacy, retailer interactions, and the evolving online shopping experience.",
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': 'SALESFORCE CEO MARC BENIOFF HAS THOUGHTS ON AI AGENTS, AUTOMATION,\r\nAND THE FUTURE OF YOUR JOB',
#   'url': 'https://www.bigtechnology.com/p/salesforce-ceo-marc-benioff-has-thoughts?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Salesforce CEO Marc Benioff envisions companies creating AI agents to handle customer service and sales tasks by leveraging their existing data and policies, positioning Salesforce as the key enabler of this transformation. He argues that AI-driven automation will enhance productivity rather than eliminate jobs, allowing businesses to operate more efficiently and expand without increasing human labor. Benioff highlights this shift as a critical moment in business evolution, providing a competitive edge against rivals and reshaping traditional workflows.',
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': 'DEMO: DECOUPLED MOMENTUM OPTIMIZATION',
#   'url': 'https://arxiv.org/abs/2411.19870?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': '2.5x faster, 100x less communication volume, and written by the original Adam author. This new optimizer boasts impressive performance for language model training with some strong improvements over the current dominant optimization schemes.',
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': 'REWARD HACKING',
#   'url': 'https://lilianweng.github.io/posts/2024-11-28-reward-hacking/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Lilian Weng has another great blog post discussing the challenge of Reward Hacking within language model alignment. It is one of the major challenges preventing models from being deployed into production scenarios.',
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': 'OPENAI TARGETS 1BN USERS IN NEXT PHASE OF GROWTH',
#   'url': 'https://links.tldrnewsletter.com/SMcvfH',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "OpenAI aims to reach 1 billion users by launching new AI agents, building AI infrastructure, and integrating ChatGPT with Apple devices. The company is investing heavily in AI development and infrastructure to maintain a competitive edge against rivals like Google and Microsoft. OpenAI is navigating political complexities while pushing for US-led AI advancements over China's influence.",
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': "GOOGLE'S PLAN TO KEEP AI OUT OF SEARCH TRIAL REMEDIES ISN'T GOING\r\nVERY WELL",
#   'url': 'https://arstechnica.com/tech-policy/2024/11/google-drags-ai-rivals-into-search-trial-as-judge-entertains-ai-remedies/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "US District Judge Amit Mehta suggests AI could play a significant role in developing remedies following the government's win in the Google search monopoly trial, potentially affecting Google's AI products. The DOJ has proposed remedies to prevent Google from using AI to maintain its market dominance, including restrictions on exclusive agreements and investments in AI. Microsoft is resisting Google's demands for confidential AI deal details, arguing relevance. OpenAI may be compelled to share data amidst these considerations.",
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': 'UV GUIDE TO PYTORCH',
#   'url': 'https://docs.astral.sh/uv/guides/integration/pytorch/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Documentation on how to use the new package manager UV to install PyTorch.',
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': 'AI COMPANY MISTRAL IS LATEST EUROPEAN STARTUP TO EYE EXPANSION IN\r\nSILICON VALLEY',
#   'url': 'https://www.semafor.com/article/11/27/2024/ai-company-mistral-is-latest-european-startup-to-eye-expansion-in-silicon-valley?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'European AI startup Mistral, known for open-weight LLMs, is expanding to Palo Alto to access Silicon Valley talent and resources.',
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': 'OPENAI GETS NEW $1.5 BILLION INVESTMENT FROM SOFTBANK, ALLOWING\r\nEMPLOYEES TO SELL SHARES IN A TENDER OFFER',
#   'url': 'https://www.cnbc.com/2024/11/26/openai-gets-1point5-billion-investment-from-softbank-in-tender-offer.html?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'OpenAI is allowing employees to sell $1.5 billion worth of shares to SoftBank, reflecting growing investor interest in AI.',
#   'date_source': 'Tue, 3 Dec 2024 14:13:10 +0000'},
#  {'title': "ELON MUSK SEEKS TO BLOCK OPENAI'S FOR-PROFIT CONVERSION AGAIN",
#   'url': 'https://www.theverge.com/2024/11/30/24309697/elon-musk-openai-lawsuit-for-profit-transition-preliminary-injunction?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Elon Musk's legal team has filed a motion to prevent OpenAI from transitioning to a for-profit model citing alleged antitrust violations and financial risks. The motion claims CEO Sam Altman's actions could leave the company unable to pay damages if Musk wins his lawsuit.",
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'PERPLEXITY MULLS GETTING INTO HARDWARE',
#   'url': 'https://techcrunch.com/2024/11/26/perplexity-mulls-getting-into-hardware/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Perplexity\'s CEO plans to develop a "simple, under $50" AI device for voice-to-voice interactions. This aligns with a broader trend of AI startups exploring hardware to enable new interactions, although historical challenges in AI hardware highlight risks. Perplexity, with substantial funding, aims to avoid pitfalls faced by others like Humane\'s Ai Pin.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': "INFLECTION AI CEO SAYS IT'S DONE TRYING TO MAKE NEXT-GENERATION AI\r\nMODELS",
#   'url': 'https://techcrunch.com/2024/11/26/inflection-ceo-says-its-done-competing-to-make-next-generation-ai-models/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Inflection AI shifted its focus from developing cutting-edge AI models to providing AI tools for enterprise customers, leveraging current AI models. It has acquired three AI startups to strengthen offerings and is open to licensing models from former competitors. CEO Sean White says the company is focused on practical applications over frontier model development, highlighting on-premise AI solutions for enterprise data security.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'INTELLECT-1 RELEASE: THE FIRST GLOBALLY TRAINED 10B PARAMETER MODEL',
#   'url': 'https://www.primeintellect.ai/blog/intellect-1-release?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'INTELLECT-1 is a 10B parameter model trained on 1T tokens with hardware distributed around the globe. The benchmarks are reasonable, and the MFU of 30%+ is amazing given the distributed nature of training. If the results hold, this is a substantial improvement for decentralized large model training.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'DETECT AND LEARN UNSEEN OBJECTS',
#   'url': 'https://arxiv.org/abs/2411.18207v1?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "This new framework pushes object detection into open-world scenarios by teaching AI to identify and learn from objects it hasn't seen before.",
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'MAKING UNDERWATER IMAGES CLEAR',
#   'url': 'https://arxiv.org/abs/2411.18296v1?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'HUPE is an AI-powered method that improves underwater image clarity while preserving details critical for other tasks like object detection.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'MAPPING THE IONOSPHERE WITH THE POWER OF ANDROID',
#   'url': 'https://research.google/blog/mapping-the-ionosphere-with-the-power-of-android/?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Google researchers were able to accurately map the Ionosphere by using GPS fluctuations and some clever algorithmic work. The task is usually expensive and time consuming. This effort can assist with various climate solutions.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'INTRODUCING LTNTORCH',
#   'url': 'https://arxiv.org/abs/2409.16045v1?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'Logic Tensor Networks (LTN) merge deep learning with logical reasoning, allowing neural models to learn by optimizing a knowledge base of logical formulas.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'REFINING PRETRAINING DATA PROGRAMMATICALLY',
#   'url': 'https://gair-nlp.github.io/ProX/homepage.html?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'ProX is a framework that treats data refinement as a programming task, allowing models to apply fine-grained operations to individual examples at scale. It improves the quality of pre-training corpora by using small language models to generate programs.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'CHATS WITH VIDEOS IN REAL TIME',
#   'url': 'https://huggingface.co/wangyueqian/MMDuet?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'MMDuet is a novel "video-text duet" interaction format for VideoLLMs that allows AI to provide real-time responses as videos play. The approach mimics a dialogue where both users and AI can exchange messages during playback.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'BUILDING LLMS IS PROBABLY NOT GOING BE A BRILLIANT BUSINESS',
#   'url': 'https://calpaterson.com/porter.html?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "LLM makers like OpenAI face significant challenges due to industry structure, notably NVIDIA's pricing power as the key chip supplier and high buyer price sensitivity and competition. Many AI companies raise substantial capital but struggle with profitability, similar to historical tech firms like Netscape. Despite this, the technology itself may still advance. AI businesses might succeed by leveraging existing models rather than developing new ones.",
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'ROX',
#   'url': 'https://www.notboring.co/p/rox?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "A new AI-native CRM, Rox, aims to disrupt Salesforce by leveraging AI's ability to manage unstructured data and integrate with data warehouses. Rox's strategy focuses on enhancing top sales performers through AI-powered agents while securing customer data for future AI developments. Investors have shown confidence with $50M in funding, betting on Rox as AI capabilities continue to improve.",
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'PLAYAI RAISES $21M FUNDING AND RELEASES A NEW VOICE MODEL',
#   'url': 'https://blog.play.ai/blog/21m-funding?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': 'PlayAI raised $21 Million to advance voice-first AI interfaces and models and introduced Play Dialog, a state-of-the-art multi-turn speech model.',
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'ANTHROPIC SAYS CLAUDE AI CAN MATCH YOUR UNIQUE WRITING STYLE',
#   'url': 'https://www.theverge.com/2024/11/26/24306575/anthropic-claude-ai-custom-style-presets?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "Anthropic's Claude AI now offers customizable response styles, allowing users to adjust tone and length for different writing tasks.",
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'},
#  {'title': 'CONVERTING GPT TO LLAMA',
#   'url': 'https://github.com/rasbt/LLMs-from-scratch/tree/main/ch05/07_gpt_to_llama?utm_source=tldrai',
#   'source_of_the_news': 'TLDR AI <dan@tldrnewsletter.com>',
#   'news_summary': "This repository contains code for converting a GPT implementation to Meta AI's Llama.",
#   'date_source': 'Mon, 2 Dec 2024 14:29:42 +0000'}]

# %%
runner_scoring(news_stories)
# Out:
#                                                 title  \
# 0                               OPENAI O1 SYSTEM CARD
# 1       PERPLEXITY EXPANDING IT'S PUBLISHER'S PROGRAM
# 2   DEEPMIND'S GENIE 2 CAN GENERATE INTERACTIVE WO...
# 3                                         PALIGEMMA 2
# 4                      LAND COVER MAPPING WITH ASANET
# 5        FASTER MULTI-MODAL MODELS WITH TOKEN MERGING
# 6                                NEW FISH AUDIO MODEL
# 7                        OPENAI PARTNERS WITH ANDURIL
# 8   KEY LEADERS BEHIND GOOGLE'S VIRAL NOTEBOOKLM A...
# 9                                          GUI AGENTS
# 10  SAM ALTMAN SAYS ARTIFICIAL GENERAL INTELLIGENC...
# 11                          OPENAI 12 DAYS OF SHIPMAS
# 12                        META'S NUCLEAR ENERGY PLANS
# 13                     AWS REINVENT TOP ANNOUNCEMENTS
# 14      GENIE 2: A LARGE-SCALE FOUNDATION WORLD MODEL
# 15                                   MOTION PROMPTING
# 16                         DYNAMIC 4-BIT QUANTIZATION
# 17            OPTIMIZING AI INFERENCE AT CHARACTER AI
# 18  CERTAIN NAMES MAKE CHATGPT GRIND TO A HALT, AN...
# 19               FINETUNING LLM JUDGES FOR EVALUATION
# 20                                               FLOW
# 21                    THE GEN AI BRIDGE TO THE FUTURE
# 22  WORLD LABS' AI CAN GENERATE INTERACTIVE 3D SCE...
# 23                      ELEVEN LABS CONVERSATIONAL AI
# 24  CLAUDE MODELS NOW FASTER AND SMARTER ON AWS TR...
# 25                               AMAZON LAUNCHES NOVA
# 26  DIFFUSION MEETS FLOW MATCHING: TWO SIDES OF TH...
# 27  RESTRUCTURING VECTOR QUANTIZATION WITH THE ROT...
# 28              LAYOUT GENERATION WITH DIFFUSION GANS
# 29  A SYSTEM OF AGENTS BRINGS SERVICE-AS-SOFTWARE ...
# 30  AI MUSIC IS MORE REALISTIC THAN EVER: MEET SUN...
# 31  BLUESKY'S OPEN API MEANS ANYONE CAN SCRAPE YOU...
# 32                                            AISUITE
# 33  OVER ½ OF LONG POSTS ON LINKEDIN ARE LIKELY AI...
# 34               GOOGLE LAUNCHES THE LONDON AI CAMPUS
# 35                     ADS MIGHT BE COMING TO CHATGPT
# 36  THE RACE IS ON TO MAKE AI AGENTS DO YOUR ONLIN...
# 37  SALESFORCE CEO MARC BENIOFF HAS THOUGHTS ON AI...
# 38              DEMO: DECOUPLED MOMENTUM OPTIMIZATION
# 39                                     REWARD HACKING
# 40   OPENAI TARGETS 1BN USERS IN NEXT PHASE OF GROWTH
# 41  GOOGLE'S PLAN TO KEEP AI OUT OF SEARCH TRIAL R...
# 42                                UV GUIDE TO PYTORCH
# 43  AI COMPANY MISTRAL IS LATEST EUROPEAN STARTUP ...
# 44  OPENAI GETS NEW $1.5 BILLION INVESTMENT FROM S...
# 45  ELON MUSK SEEKS TO BLOCK OPENAI'S FOR-PROFIT C...
# 46             PERPLEXITY MULLS GETTING INTO HARDWARE
# 47  INFLECTION AI CEO SAYS IT'S DONE TRYING TO MAK...
# 48  INTELLECT-1 RELEASE: THE FIRST GLOBALLY TRAINE...
# 49                    DETECT AND LEARN UNSEEN OBJECTS
# 50                     MAKING UNDERWATER IMAGES CLEAR
# 51   MAPPING THE IONOSPHERE WITH THE POWER OF ANDROID
# 52                               INTRODUCING LTNTORCH
# 53         REFINING PRETRAINING DATA PROGRAMMATICALLY
# 54                     CHATS WITH VIDEOS IN REAL TIME
# 55  BUILDING LLMS IS PROBABLY NOT GOING BE A BRILL...
# 56                                                ROX
# 57  PLAYAI RAISES $21M FUNDING AND RELEASES A NEW ...
# 58  ANTHROPIC SAYS CLAUDE AI CAN MATCH YOUR UNIQUE...
# 59                            CONVERTING GPT TO LLAMA
#
#                                                   url news_provider  \
# 0             https://links.tldrnewsletter.com/xS4pwo
# 1             https://links.tldrnewsletter.com/UUkpwY
# 2   https://techcrunch.com/2024/12/04/deepminds-ge...
# 3   https://arxiv.org/abs/2412.03555?utm_source=tl...
# 4   https://arxiv.org/abs/2412.02044v1?utm_source=...
# 5   https://arxiv.org/abs/2412.03248v1?utm_source=...
# 6   https://threadreaderapp.com/thread/18643709334...
# 7   https://www.cnbc.com/2024/12/04/openai-partner...
# 8   https://techcrunch.com/2024/12/04/key-leaders-...
# 9   https://vyokky.github.io/LLM-Brained-GUI-Agent...
# 10  https://www.nytimes.com/video/business/1000000...
# 11  https://threadreaderapp.com/thread/18643354612...
# 12  https://sustainability.atmeta.com/blog/2024/12...
# 13  https://aws.amazon.com/blogs/aws/top-announcem...
# 14  https://deepmind.google/discover/blog/genie-2-...
# 15  https://motion-prompting.github.io/?utm_source...
# 16  https://unsloth.ai/blog/dynamic-4bit?utm_sourc...
# 17  https://research.character.ai/optimizing-ai-in...
# 18  https://arstechnica.com/information-technology...
# 19  https://cameronrwolfe.substack.com/p/finetuned...
# 20  https://github.com/lmnr-ai/flow?utm_source=tldrai
# 21  https://stratechery.com/2024/the-gen-ai-bridge...
# 22  https://techcrunch.com/2024/12/02/world-labs-a...
# 23  https://elevenlabs.io/conversational-ai?utm_so...
# 24  https://www.anthropic.com/news/trainium2-and-d...
# 25  https://aws.amazon.com/blogs/aws/introducing-a...
# 26  https://diffusionflow.github.io/?utm_source=tl...
# 27  https://arxiv.org/abs/2410.06424?utm_source=tl...
# 28  https://arxiv.org/abs/2412.00381v1?utm_source=...
# 29  https://foundationcapital.com/system-of-agents...
# 30  https://www.rollingstone.com/music/music-featu...
# 31  https://techcrunch.com/2024/11/27/blueskys-ope...
# 32  https://github.com/andrewyng/aisuite?utm_sourc...
# 33  https://originality.ai/blog/ai-content-publish...
# 34  https://blog.google/around-the-globe/google-eu...
# 35  https://techcrunch.com/2024/12/02/ads-might-be...
# 36  https://techcrunch.com/2024/12/02/the-race-is-...
# 37  https://www.bigtechnology.com/p/salesforce-ceo...
# 38  https://arxiv.org/abs/2411.19870?utm_source=tl...
# 39  https://lilianweng.github.io/posts/2024-11-28-...
# 40            https://links.tldrnewsletter.com/SMcvfH
# 41  https://arstechnica.com/tech-policy/2024/11/go...
# 42  https://docs.astral.sh/uv/guides/integration/p...
# 43  https://www.semafor.com/article/11/27/2024/ai-...
# 44  https://www.cnbc.com/2024/11/26/openai-gets-1p...
# 45  https://www.theverge.com/2024/11/30/24309697/e...
# 46  https://techcrunch.com/2024/11/26/perplexity-m...
# 47  https://techcrunch.com/2024/11/26/inflection-c...
# 48  https://www.primeintellect.ai/blog/intellect-1...
# 49  https://arxiv.org/abs/2411.18207v1?utm_source=...
# 50  https://arxiv.org/abs/2411.18296v1?utm_source=...
# 51  https://research.google/blog/mapping-the-ionos...
# 52  https://arxiv.org/abs/2409.16045v1?utm_source=...
# 53  https://gair-nlp.github.io/ProX/homepage.html?...
# 54  https://huggingface.co/wangyueqian/MMDuet?utm_...
# 55  https://calpaterson.com/porter.html?utm_source...
# 56   https://www.notboring.co/p/rox?utm_source=tldrai
# 57  https://blog.play.ai/blog/21m-funding?utm_sour...
# 58  https://www.theverge.com/2024/11/26/24306575/a...
# 59  https://github.com/rasbt/LLMs-from-scratch/tre...
#
#                   source_of_the_news text  \
# 0   TLDR AI <dan@tldrnewsletter.com>
# 1   TLDR AI <dan@tldrnewsletter.com>
# 2   TLDR AI <dan@tldrnewsletter.com>
# 3   TLDR AI <dan@tldrnewsletter.com>
# 4   TLDR AI <dan@tldrnewsletter.com>
# 5   TLDR AI <dan@tldrnewsletter.com>
# 6   TLDR AI <dan@tldrnewsletter.com>
# 7   TLDR AI <dan@tldrnewsletter.com>
# 8   TLDR AI <dan@tldrnewsletter.com>
# 9   TLDR AI <dan@tldrnewsletter.com>
# 10  TLDR AI <dan@tldrnewsletter.com>
# 11  TLDR AI <dan@tldrnewsletter.com>
# 12  TLDR AI <dan@tldrnewsletter.com>
# 13  TLDR AI <dan@tldrnewsletter.com>
# 14  TLDR AI <dan@tldrnewsletter.com>
# 15  TLDR AI <dan@tldrnewsletter.com>
# 16  TLDR AI <dan@tldrnewsletter.com>
# 17  TLDR AI <dan@tldrnewsletter.com>
# 18  TLDR AI <dan@tldrnewsletter.com>
# 19  TLDR AI <dan@tldrnewsletter.com>
# 20  TLDR AI <dan@tldrnewsletter.com>
# 21  TLDR AI <dan@tldrnewsletter.com>
# 22  TLDR AI <dan@tldrnewsletter.com>
# 23  TLDR AI <dan@tldrnewsletter.com>
# 24  TLDR AI <dan@tldrnewsletter.com>
# 25  TLDR AI <dan@tldrnewsletter.com>
# 26  TLDR AI <dan@tldrnewsletter.com>
# 27  TLDR AI <dan@tldrnewsletter.com>
# 28  TLDR AI <dan@tldrnewsletter.com>
# 29  TLDR AI <dan@tldrnewsletter.com>
# 30  TLDR AI <dan@tldrnewsletter.com>
# 31  TLDR AI <dan@tldrnewsletter.com>
# 32  TLDR AI <dan@tldrnewsletter.com>
# 33  TLDR AI <dan@tldrnewsletter.com>
# 34  TLDR AI <dan@tldrnewsletter.com>
# 35  TLDR AI <dan@tldrnewsletter.com>
# 36  TLDR AI <dan@tldrnewsletter.com>
# 37  TLDR AI <dan@tldrnewsletter.com>
# 38  TLDR AI <dan@tldrnewsletter.com>
# 39  TLDR AI <dan@tldrnewsletter.com>
# 40  TLDR AI <dan@tldrnewsletter.com>
# 41  TLDR AI <dan@tldrnewsletter.com>
# 42  TLDR AI <dan@tldrnewsletter.com>
# 43  TLDR AI <dan@tldrnewsletter.com>
# 44  TLDR AI <dan@tldrnewsletter.com>
# 45  TLDR AI <dan@tldrnewsletter.com>
# 46  TLDR AI <dan@tldrnewsletter.com>
# 47  TLDR AI <dan@tldrnewsletter.com>
# 48  TLDR AI <dan@tldrnewsletter.com>
# 49  TLDR AI <dan@tldrnewsletter.com>
# 50  TLDR AI <dan@tldrnewsletter.com>
# 51  TLDR AI <dan@tldrnewsletter.com>
# 52  TLDR AI <dan@tldrnewsletter.com>
# 53  TLDR AI <dan@tldrnewsletter.com>
# 54  TLDR AI <dan@tldrnewsletter.com>
# 55  TLDR AI <dan@tldrnewsletter.com>
# 56  TLDR AI <dan@tldrnewsletter.com>
# 57  TLDR AI <dan@tldrnewsletter.com>
# 58  TLDR AI <dan@tldrnewsletter.com>
# 59  TLDR AI <dan@tldrnewsletter.com>
#
#                                          news_summary  \
# 0   This report outlines the safety work carried o...
# 1   Perplexity has added over a dozen internationa...
# 2   DeepMind's Genie 2 is an advanced AI model tha...
# 3   Paligemma 2 is one of the best VLMs on the mar...
# 4   The Asymmetric Semantic Aligning Network (ASAN...
# 5   Researchers have developed a training-free met...
# 6   The newest Fish Audio 1.5 is currently #2 on T...
# 7   OpenAI and defense company Anduril have partne...
# 8   Three key Google NotebookLM members have left ...
# 9   A collection of research papers and projects o...
# 10  Sam Altman, CEO of OpenAI, stated at the DealB...
# 11  OpenAI will be having 12 live streams over the...
# 12  Meta announced plans to collaborate with nucle...
# 13  AWS announced various additions and tools incl...
# 14  Genie 2 is a large scale latent diffusion mode...
# 15  Motion Prompting is a method that trains a vid...
# 16  The Unsloth team aims to shrink a 20GB languag...
# 17  Character AI has a strong inference pipeline. ...
# 18  OpenAI's ChatGPT employs hard-coded filters to...
# 19  Evaluating LLMs has become challenging due to ...
# 20  Flow is a lightweight engine for creating flex...
# 21  Generative AI is set to revolutionize wearable...
# 22  World Labs, founded by AI expert Fei-Fei Li, h...
# 23  Eleven Labs has launched a new conversational ...
# 24  Claude models are being optimized for AWS' adv...
# 25  Amazon Nova introduces a suite of multimodal m...
# 26  This post talks through some of the literature...
# 27  Vector Quantization relies on gradient estimat...
# 28  DogLayout is a hybrid model that combines GANs...
# 29  AI is transitioning software from a tool to au...
# 30  Suno has become the fifth most-used generative...
# 31  Bluesky isn't using user content to train AI, ...
# 32  aisuite provides a unified interface for seaml...
# 33  Since ChatGPT's launch, LinkedIn has seen an 1...
# 34  The AI Campus is an educational pilot to suppo...
# 35  OpenAI is considering an advertising business ...
# 36  Tech companies are developing AI shopping agen...
# 37  Salesforce CEO Marc Benioff envisions companie...
# 38  2.5x faster, 100x less communication volume, a...
# 39  Lilian Weng has another great blog post discus...
# 40  OpenAI aims to reach 1 billion users by launch...
# 41  US District Judge Amit Mehta suggests AI could...
# 42  Documentation on how to use the new package ma...
# 43  European AI startup Mistral, known for open-we...
# 44  OpenAI is allowing employees to sell $1.5 bill...
# 45  Elon Musk's legal team has filed a motion to p...
# 46  Perplexity's CEO plans to develop a "simple, u...
# 47  Inflection AI shifted its focus from developin...
# 48  INTELLECT-1 is a 10B parameter model trained o...
# 49  This new framework pushes object detection int...
# 50  HUPE is an AI-powered method that improves und...
# 51  Google researchers were able to accurately map...
# 52  Logic Tensor Networks (LTN) merge deep learnin...
# 53  ProX is a framework that treats data refinemen...
# 54  MMDuet is a novel "video-text duet" interactio...
# 55  LLM makers like OpenAI face significant challe...
# 56  A new AI-native CRM, Rox, aims to disrupt Sale...
# 57  PlayAI raised $21 Million to advance voice-fir...
# 58  Anthropic's Claude AI now offers customizable ...
# 59  This repository contains code for converting a...
#
#                        date_source
# 0   Fri, 6 Dec 2024 14:16:24 +0000
# 1   Fri, 6 Dec 2024 14:16:24 +0000
# 2   Fri, 6 Dec 2024 14:16:24 +0000
# 3   Fri, 6 Dec 2024 14:16:24 +0000
# 4   Fri, 6 Dec 2024 14:16:24 +0000
# 5   Fri, 6 Dec 2024 14:16:24 +0000
# 6   Fri, 6 Dec 2024 14:16:24 +0000
# 7   Fri, 6 Dec 2024 14:16:24 +0000
# 8   Fri, 6 Dec 2024 14:16:24 +0000
# 9   Fri, 6 Dec 2024 14:16:24 +0000
# 10  Fri, 6 Dec 2024 14:16:24 +0000
# 11  Thu, 5 Dec 2024 14:13:29 +0000
# 12  Thu, 5 Dec 2024 14:13:29 +0000
# 13  Thu, 5 Dec 2024 14:13:29 +0000
# 14  Thu, 5 Dec 2024 14:13:29 +0000
# 15  Thu, 5 Dec 2024 14:13:29 +0000
# 16  Thu, 5 Dec 2024 14:13:29 +0000
# 17  Thu, 5 Dec 2024 14:13:29 +0000
# 18  Thu, 5 Dec 2024 14:13:29 +0000
# 19  Thu, 5 Dec 2024 14:13:29 +0000
# 20  Thu, 5 Dec 2024 14:13:29 +0000
# 21  Thu, 5 Dec 2024 14:13:29 +0000
# 22  Thu, 5 Dec 2024 14:13:29 +0000
# 23  Wed, 4 Dec 2024 14:15:46 +0000
# 24  Wed, 4 Dec 2024 14:15:46 +0000
# 25  Wed, 4 Dec 2024 14:15:46 +0000
# 26  Wed, 4 Dec 2024 14:15:46 +0000
# 27  Wed, 4 Dec 2024 14:15:46 +0000
# 28  Wed, 4 Dec 2024 14:15:46 +0000
# 29  Wed, 4 Dec 2024 14:15:46 +0000
# 30  Wed, 4 Dec 2024 14:15:46 +0000
# 31  Wed, 4 Dec 2024 14:15:46 +0000
# 32  Wed, 4 Dec 2024 14:15:46 +0000
# 33  Wed, 4 Dec 2024 14:15:46 +0000
# 34  Wed, 4 Dec 2024 14:15:46 +0000
# 35  Tue, 3 Dec 2024 14:13:10 +0000
# 36  Tue, 3 Dec 2024 14:13:10 +0000
# 37  Tue, 3 Dec 2024 14:13:10 +0000
# 38  Tue, 3 Dec 2024 14:13:10 +0000
# 39  Tue, 3 Dec 2024 14:13:10 +0000
# 40  Tue, 3 Dec 2024 14:13:10 +0000
# 41  Tue, 3 Dec 2024 14:13:10 +0000
# 42  Tue, 3 Dec 2024 14:13:10 +0000
# 43  Tue, 3 Dec 2024 14:13:10 +0000
# 44  Tue, 3 Dec 2024 14:13:10 +0000
# 45  Mon, 2 Dec 2024 14:29:42 +0000
# 46  Mon, 2 Dec 2024 14:29:42 +0000
# 47  Mon, 2 Dec 2024 14:29:42 +0000
# 48  Mon, 2 Dec 2024 14:29:42 +0000
# 49  Mon, 2 Dec 2024 14:29:42 +0000
# 50  Mon, 2 Dec 2024 14:29:42 +0000
# 51  Mon, 2 Dec 2024 14:29:42 +0000
# 52  Mon, 2 Dec 2024 14:29:42 +0000
# 53  Mon, 2 Dec 2024 14:29:42 +0000
# 54  Mon, 2 Dec 2024 14:29:42 +0000
# 55  Mon, 2 Dec 2024 14:29:42 +0000
# 56  Mon, 2 Dec 2024 14:29:42 +0000
# 57  Mon, 2 Dec 2024 14:29:42 +0000
# 58  Mon, 2 Dec 2024 14:29:42 +0000
# 59  Mon, 2 Dec 2024 14:29:42 +0000
